# %% [markdown]
# # Distribution of stats of NBA

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('players_stats_by_season_full_details.csv')

# %%
df.head()
# Out:
#   League       Season           Stage         Player Team  GP     MIN  FGM  \
# 0    NBA  2009 - 2010  Regular_Season   Kevin Durant  OKC  82  3239.3  794
# 1    NBA  2009 - 2010  Regular_Season   LeBron James  CLE  76  2965.6  768
# 2    NBA  2009 - 2010  Regular_Season    Dwyane Wade  MIA  77  2792.4  719
# 3    NBA  2009 - 2010  Regular_Season  Dirk Nowitzki  DAL  81  3038.8  720
# 4    NBA  2009 - 2010  Regular_Season    Kobe Bryant  LAL  73  2835.4  716
#
#     FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  1668  128  ...  2472      1988.0          Sep  Sep 29, 1988     6-9
# 1  1528  129  ...  2258      1984.0          Dec  Dec 30, 1984     6-8
# 2  1511   73  ...  2045      1982.0          Jan  Jan 17, 1982     6-4
# 3  1496   51  ...  2027      1978.0          Jun  Jun 19, 1978     7-0
# 4  1569   99  ...  1970      1978.0          Aug  Aug 23, 1978     6-6
#
#    height_cm  weight  weight_kg    nationality  \
# ...

# %%
db = df[df['League'] == 'NBA']

# %%
db.head()
# Out:
#   League       Season           Stage         Player Team  GP     MIN  FGM  \
# 0    NBA  2009 - 2010  Regular_Season   Kevin Durant  OKC  82  3239.3  794
# 1    NBA  2009 - 2010  Regular_Season   LeBron James  CLE  76  2965.6  768
# 2    NBA  2009 - 2010  Regular_Season    Dwyane Wade  MIA  77  2792.4  719
# 3    NBA  2009 - 2010  Regular_Season  Dirk Nowitzki  DAL  81  3038.8  720
# 4    NBA  2009 - 2010  Regular_Season    Kobe Bryant  LAL  73  2835.4  716
#
#     FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  1668  128  ...  2472      1988.0          Sep  Sep 29, 1988     6-9
# 1  1528  129  ...  2258      1984.0          Dec  Dec 30, 1984     6-8
# 2  1511   73  ...  2045      1982.0          Jan  Jan 17, 1982     6-4
# 3  1496   51  ...  2027      1978.0          Jun  Jun 19, 1978     7-0
# 4  1569   99  ...  1970      1978.0          Aug  Aug 23, 1978     6-6
#
#    height_cm  weight  weight_kg    nationality  \
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3792 entries, 0 to 3791
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       3792 non-null   object
#  1   Season       3792 non-null   object
#  2   Stage        3792 non-null   object
#  3   Player       3792 non-null   object
#  4   Team         3792 non-null   object
#  5   GP           3792 non-null   int64
#  6   MIN          3792 non-null   float64
#  7   FGM          3792 non-null   int64
#  8   FGA          3792 non-null   int64
#  9   3PM          3792 non-null   int64
#  10  3PA          3792 non-null   int64
#  11  FTM          3792 non-null   int64
#  12  FTA          3792 non-null   int64
#  13  TOV          3792 non-null   int64
#  14  PF           3792 non-null   int64
#  15  ORB          3792 non-null   int64
#  16  DRB          3792 non-null   int64
#  17  REB          3792 non-null   int64
# ...

# %%
db
# Out:
#      League       Season           Stage          Player Team  GP     MIN  \
# 0       NBA  2009 - 2010  Regular_Season    Kevin Durant  OKC  82  3239.3
# 1       NBA  2009 - 2010  Regular_Season    LeBron James  CLE  76  2965.6
# 2       NBA  2009 - 2010  Regular_Season     Dwyane Wade  MIA  77  2792.4
# 3       NBA  2009 - 2010  Regular_Season   Dirk Nowitzki  DAL  81  3038.8
# 4       NBA  2009 - 2010  Regular_Season     Kobe Bryant  LAL  73  2835.4
# ...     ...          ...             ...             ...  ...  ..     ...
# 3787    NBA  2018 - 2019        Playoffs   Davis Bertans  SAS   5    78.8
# 3788    NBA  2018 - 2019        Playoffs    Jonah Bolden  PHI  10    79.1
# 3789    NBA  2018 - 2019        Playoffs  Garrett Temple  LAC   6    62.8
# 3790    NBA  2018 - 2019        Playoffs    Jared Dudley  BRK   4    82.2
# 3791    NBA  2018 - 2019        Playoffs  Treveon Graham  BRK   5    78.7
#
#       FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  \
# ...

# %% [markdown]
# ### We have everything set, now we shall start the analysis, getting the mean of each numerical stats, which will be used on other parts of the project.

# %%
dic_mean = {'GP': db['GP'].mean(),'MIN': db['MIN'].mean(), 'FGM': db['FGM'].mean(), 'REB': db['REB'].mean(), 'FGA': db['FGA'].mean(),
           '3PM': db['3PM'].mean(),'3PA': db['3PA'].mean(),'FTM': db['FTM'].mean(),'FTA': db['FTA'].mean(),'TOV': db['TOV'].mean(),'PF': db['PF'].mean(),'ORB': db['ORB'].mean(),
           'DRB': db['DRB'].mean(),'AST': db['AST'].mean(),'STL': db['STL'].mean(),'BLK': db['BLK'].mean(),'PTS': db['PTS'].mean(),'height_cm': db['height_cm'].mean(),
           'weight_kg': db['weight_kg'].mean()}

# %% [markdown]
# #### Let's check the mean for height and weight, and later analyze the distribution of them.

# %%
[dic_mean['height_cm'], dic_mean['weight_kg']]
# Out:
# [200.793776371308, 101.05801687763713]

# %%
figure, plot = plt.subplots(1,2)
sns.displot(data=db, x = 'height_cm', ax = plot[0], color='green')
sns.displot(data=db, x = 'weight_kg', ax = plot[1], color= 'red')
plot.show()
# Out:
# C:\Users\villa\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\villa\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1276\1781331069.py in <module>
#       2 sns.displot(data=db, x = 'height_cm', ax = plot[0], color='green')
#       3 sns.displot(data=db, x = 'weight_kg', ax = plot[1], color= 'red')
# ----> 4 plot.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %% [markdown]
# ### That's just the start, the next files will be more complex and will take much more data analysis into account.
